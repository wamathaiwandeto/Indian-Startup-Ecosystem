# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\wycliffe\anaconda3\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc     
from dotenv import dotenv_values    #import the dotenv_values function from the dotenv package
import pandas as pd
import warnings 

warnings.filterwarnings('ignore')

# %%
# Load environment variables from .env file into a dictionary
environment_variables = dotenv_values('.env')

# Get the values for the credentials you set in the '.env' file
server = environment_variables.get("server")
database = environment_variables.get("database")
username = environment_variables.get("username")
password = environment_variables.get("password")

# %%
# Create a connection string
connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password};MARS_Connection=yes;MinProtocolVersion=TLSv1.2;"

# %%
# Use the connect method of the pyodbc library and pass in the connection string.
# This will connect to the server and might take a few seconds to be complete. 
# Check your internet connection if it takes more time than necessary

connection = pyodbc.connect(connection_string)

# %%
# Now the sql query to get the data is what what you see below. 
# Note that you will not have permissions to insert delete or update this database table. 

query = "SELECT * FROM dbo.LP1_startup_funding2021"

data = pd.read_sql(query, connection)

# %% [markdown]
# ## Data

# %%
data.sample(25)
# Out:
#            Company_Brand  Founded             HeadQuarter  \
# 943      RENEE Cosmetics   2019.0               Ahmedabad
# 104       Advantage Club   2014.0                  Mumbai
# 190               Khabri   2017.0                Gurugram
# 88            Factors.AI   2020.0               Bangalore
# 41          Puresh Daily   2019.0                  Ranchi
# 606              Spardha   2016.0                    Pune
# 40                  iBus   2010.0               Bangalore
# 369           YourPhysio   2020.0                  Nagpur
# 922                 Defy   2021.0               Bangalore
# 257              MoEVing   2021.0         Gurugram\t#REF!
# 653                MSMEx   2019.0                 Andheri
# 256   Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 859              Sarathi   2020.0                 Jodhpur
# 246           NephroPlus   2009.0               Hyderabad
# 836              FanCode   2019.0                  Mumbai
# 687             ApnaKlub   2020.0               Bangalore
# 611               Now&Me   2018.0               New Delhi
# 75             PumPumPum   2018.0                Gurugram
# 727             CityMall   2019.0                Gurugram
# 173               upGrad   2015.0                  Mumbai
# 1189          bitsCrunch   2020.0                 Chennai
# 728               Janani   2020.0               Bangalore
# 332       Express Stores   2019.0                Gurugram
# 1                 upGrad   2015.0                  Mumbai
# 847             BharatPe   2018.0               New Delhi
#
#                                                  Sector  \
# 943                                           Cosmetics
# 104                                              HRTech
# 190                                               Media
# 88                                         SaaS startup
# 41                                         Milk startup
# 606                                              EdTech
# 40                                     Telecommuncation
# 369                                          HealthTech
# 922                                  Financial Services
# 257   MoEVing is India's only Electric Mobility focu...
# 653                                              EdTech
# 256   Primary Business is Development and Manufactur...
# 859                                          HealthCare
# 246                              Hospital & Health Care
# 836                                      Sports startup
# 687                                          E-commerce
# 611                                          HealthCare
# 75                                               Rental
# 727                                          E-commerce
# 173                                              EdTech
# 1189                                         Blockchain
# 728                                           Heathcare
# 332                                          E-commerce
# 1                                                EdTech
# 847                                             FinTech
#
#                                            What_it_does  \
# 943   RENÉE Cosmetics is an Indian makeup brand empo...
# 104   Advantage Club is India's largest employee eng...
# 190   Khabri is India’s fastest growing vernacular a...
# 88    Factors.AI is a Marketing Analytics platform p...
# 41    PUREandFRES-Milk delivers fresh milk directly ...
# 606   Spardha School Of Music, Spardha Academy, Spar...
# 40    iBus Networks is an in-building connectivity s...
# 369   YourPhysio is a healthcare company on a missio...
# 922       Building India's first social crypto exchange
# 257                         Vikash Mishra, Mragank Jain
# 653   MSMEx connects micro and small Business Owners...
# 256                                        Varun Khanna
# 859   Offer a range of services like lab tests, cons...
# 246   A vision and passion of redefining healthcare ...
# 836   FanCode is a multi sport aggregator platform f...
# 687   Supporting independent businesses and retail e...
# 611   Now&Me is a safe cocoon in the form of discuss...
# 75                   Pumpumpum is a car rental company.
# 727   CityMall is a social e-commerce platform that ...
# 173   upGrad is India’s largest online higher educat...
# 1189  A consulting firm focused mainly on Data Analy...
# 728             Janani.ai is a fertility care provider.
# 332   Express Stores is a retail and omnichannel sta...
# 1        UpGrad is an online higher education platform.
# 847   BharatPe is the definitive platform for financ...
#
#                                                Founders  \
# 943   Priyank Shah, Ashutosh Valani, Aashka Goradia ...
# 104                  Sourabh Deorah, Smiti Bhatt Deorah
# 190            Pulkit Sharma, Aankit Roy, Sandeep Singh
# 88    Aravind Murthy, Praveen Das, Srikrishna Swamin...
# 41                           Manish Piyush, Ayush Kumar
# 606                 Saurabh Srivastav, Amrita Srivastav
# 40    Ram Sellaratnam, Sunil Menon and Subash Vasudevan
# 369              Dr Sheetal Mundhada, Ashutosh Mundhada
# 922      Bhagaban Behera, Sriharsha Setty, Nakul Kelkar
# 257      Anshuman Maheshwary, Dr Srihari Raju Kalidindi
# 653   Amit Kumar, Vishal Kumar, Dilip Kumar, Khushbo...
# 256                  Morgan Stanley Private Equity Asia
# 859                                         Aditi Poyam
# 246                                      Vikram Vuppala
# 836                                      Yannick Colaco
# 687                                Shruti, Manish Kumar
# 611                           Bani Singh, Drishti Gupta
# 75                          Tarun Lawadia, Sameer Kalra
# 727                            Angad Kikla, Divij Goyal
# 173    Phalgun Kompalli, Ronnie Screwvala, Mayank Kumar
# 1189                             Saravanan Jaichandaran
# 728                                      Nilay Mehrotra
# 332                           Apoorv Jain, Kartik Gupta
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 847   Ashneer Grover, Bhavik Koladiya, Shashvat Nakrani
#
#                                                Investor        Amount  \
# 943                      Equanimity Ventures, 9Unicorns      $1500000
# 104            Y Combinator, Broom Ventures, Kunal Shah      $1700000
# 190                                                None      $2000000
# 88                Elevation Partners, Emergent Ventures      $2000000
# 41              Alfa Ventures, Agility Venture Partners      $100,000
# 606                           Inflection Point Ventures       $400000
# 40                                       Morgan Stanley   $21,000,000
# 369                       Better Capital, Titan Capital      $350,000
# 922   Y Combinator, Goat VC, JAM Fund, Goodwater Cap...      $5500000
# 257                                            $5000000          Seed
# 653                              TNF Ventures, Razorpay      $1000000
# 256                                           $22000000      Series C
# 859                                                None      $100,000
# 246                               IIFL Asset Management     $24000000
# 836                                        Dream Sports   $50,000,000
# 687                  Blume Ventures, Whiteboard Capital  $Undisclosed
# 611                           Saama, Whiteboard Capital      $1000000
# 75            Kogta Financial India Limited, ICICI Bank      $700,000
# 727                 WaterBridge Ventures, SAIF Partners   $11,000,000
# 173                              India Infoline Finance     $25000000
# 1189  Covalent, Double Peak, GenBlock Capital, Ledge...       $700000
# 728               Sweta Rau, 9Unicorns Accelerator Fund    $1,000,000
# 332                       Venture Highway, Rohit Bansal    $1,000,000
# 1              Unilazer Ventures, IIFL Asset Management  $120,000,000
# 847                             Amplo, Insight Partners    $6,000,000
#
#               Stage
# 943    Pre-series A
# 104            None
# 190    Pre-series A
# 88             None
# 41             Seed
# 606   Pre-series A1
# 40             None
# 369        Pre-seed
# 922            None
# 257            None
# 653    Pre-series A
# 256            None
# 859            Seed
# 246        Series E
# 836            None
# 687    Pre-series A
# 611            None
# 75     Pre-series A
# 727        Series A
# 173            None
# 1189           Seed
# 728            Seed
# 332            Seed
# 1              None
# 847            Debt

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB
